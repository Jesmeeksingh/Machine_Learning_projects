# %% [markdown]
# <a href="https://colab.research.google.com/github/Jesmeeksingh/Machine_Learning_projects/blob/main/Univariate_data_visualisation_on_world_happiness_index.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv("/content/WHR2024.csv")

# %%
df.shape
# Out:
# (143, 11)

# %%
df.sample(5)
# Out:
#      Country name  Ladder score  upperwhisker  lowerwhisker  \
# 134      Eswatini         3.502         3.673         3.331
# 0         Finland         7.741         7.815         7.667
# 55        Hungary         6.017         6.124         5.910
# 114       Tunisia         4.422         4.505         4.338
# 109  Burkina Faso         4.548         4.686         4.410
#
#      Explained by: Log GDP per capita  Explained by: Social support  \
# 134                             1.255                         0.925
# 0                               1.844                         1.572
# 55                              1.722                         1.528
# 114                             1.306                         0.955
# 109                             0.756                         0.685
#
#      Explained by: Healthy life expectancy  \
# 134                                  0.176
# 0                                    0.695
# 55                                   0.596
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 143 entries, 0 to 142
# Data columns (total 11 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Country name                                143 non-null    object
#  1   Ladder score                                143 non-null    float64
#  2   upperwhisker                                143 non-null    float64
#  3   lowerwhisker                                143 non-null    float64
#  4   Explained by: Log GDP per capita            140 non-null    float64
#  5   Explained by: Social support                140 non-null    float64
#  6   Explained by: Healthy life expectancy       140 non-null    float64
#  7   Explained by: Freedom to make life choices  140 non-null    float64
#  8   Explained by: Generosity                    140 non-null    float64
# ...

# %%
df.describe()
# Out:
#        Ladder score  upperwhisker  lowerwhisker  \
# count    143.000000    143.000000    143.000000
# mean       5.527580      5.641175      5.413972
# std        1.170717      1.155008      1.187133
# min        1.721000      1.775000      1.667000
# 25%        4.726000      4.845500      4.606000
# 50%        5.785000      5.895000      5.674000
# 75%        6.416000      6.507500      6.319000
# max        7.741000      7.815000      7.667000
#
#        Explained by: Log GDP per capita  Explained by: Social support  \
# count                        140.000000                    140.000000
# mean                           1.378807                      1.134329
# std                            0.425098                      0.333317
# min                            0.000000                      0.000000
# 25%                            1.077750                      0.921750
# 50%                            1.431500                      1.237500
# ...

# %%
import matplotlib.pyplot as plt
plt.hist(df['Ladder score'])
# Out:
# (array([ 1.,  1.,  8.,  8., 18., 22., 22., 34., 22.,  7.]),
#  array([1.721, 2.323, 2.925, 3.527, 4.129, 4.731, 5.333, 5.935, 6.537,
#         7.139, 7.741]),
#  <BarContainer object of 10 artists>)

# %%
import seaborn as sns

# %%
sns.distplot(df['Ladder score'])
# Out:
# <ipython-input-9-3881ed31b94f>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Ladder score'])
# <Axes: xlabel='Ladder score', ylabel='Density'>

# %%
# Assuming df is your DataFrame
india_ladder_score = df[df['Country name'] == 'India']['Ladder score']
print(india_ladder_score)
# Out:
# 125    4.054
# Name: Ladder score, dtype: float64

# %%
sns.distplot(df['Explained by: Freedom to make life choices'])
# Out:
# <ipython-input-12-40963a3af06f>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Explained by: Freedom to make life choices'])
# <Axes: xlabel='Explained by: Freedom to make life choices', ylabel='Density'>

# %%
df['Explained by: Freedom to make life choices'].min()
# Out:
# 0.0

# %%
sns.boxplot(df['Explained by: Freedom to make life choices'])
# Out:
# <Axes: ylabel='Explained by: Freedom to make life choices'>
